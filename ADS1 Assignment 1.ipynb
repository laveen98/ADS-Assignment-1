# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 2016 Data Sheet

# %%
#Top 5 countries visited Sri Lanka in 2016

data16 = pd.read_csv('2016-P21.csv', index_col=None)
y16 = data16.iloc[:5, :2]

dfg = data16.groupby('Country of Residence')
dfg

y16['Country of Residence'].value_counts().plot(kind='pie', figsize = (6,6))
y16
# Out:
#   Country of Residence   TOTAL
# 0                India  356729
# 1                China  271577
# 2                   UK  188159
# 3              Germany  133275
# 4               France   96440

# %%
'''import seaborn as sns
sns.pairplot(data16.iloc[:, 1:5])
data16'''
# Out:
# 'import seaborn as sns\nsns.pairplot(data16.iloc[:, 1:5])\ndata16'

# %%
#Top 5 countries visited SL in 2016
fig = plt.figure(figsize=(5,3))
ax = fig.add_axes([0,0,1,1])
COR = y16['Country of Residence']
pop = y16['TOTAL']
ax.bar(COR,pop)
# Out:
# <BarContainer object of 5 artists>

# %%
#m16 = data16.loc["UK"]
#lines = y16.plot.line()
'''print(df.col)
uk_time_period = list(data16.iloc[2,2:]) #x-axis
time_period'''

uk_df16 = data16.iloc[2,2:]

lines = uk_df16.plot.line()

# %% [markdown]
# 2015 Data sheet

# %%
data15 = pd.read_csv('2015-P23.csv', index_col=None)
y15 = data15.iloc[:5, :2] 

dfg = data16.groupby('Country of Residence')
dfg

y15['Country of Residence'].value_counts().plot(kind='pie', figsize = (6,6))

y15
# Out:
#   Country of Residence   TOTAL
# 0                India  316247
# 1                China  214783
# 2                 U.K.  161845
# 3              Germany  115868
# 4             Maldives   90617

# %%
print(data15.iloc[2,2:])

uk_df15 = data15.iloc[2,2:]
lines = uk_df15.plot.line()
# Out:
# Jan    13410
# Feb    15212
# Mar    16191
# Apr    11233
# May     7954
# Jun     8580
# Jul    20643
# Aug    17908
# Sep    11160
# Oct     9970
# Nov    10822
# Dec    18762
# Name: 2, dtype: object

# %%
'''Tourist arrivals in september 2021'''
'''https://www.sltda.gov.lk/storage/common_media/September-Arrivals-Report97490040.pdf'''

data21sep = pd.read_csv('Tourist_arrival_Sept_2021.csv', index_col=None)
x21_sep = data21sep.sort_values(by=['September 2021'], ascending=False)
y21_sep = data21sep.iloc[:5, :2] 


plot = y21_sep.plot.pie(y='September 2021', figsize=(7, 7),)
plt.show()

y21_sep
# Out:
#   Country of Residence  September 2021
# 0                India            8528
# 1             Pakistan            1225
# 2              Germany             466
# 3       United Kingdom             309
# 4               Russia             304

# %%
'''https://www.sltda.gov.lk/storage/common_media/September-Arrivals-Report97490040.pdf'''
#Tourist Arrival on year 2020

data20 = pd.read_csv('2020_tourism.csv', index_col=None)

#data20.index = np.arange(1, len(data20))

y20 = data20.iloc[:5, :2] 


dfg = data16.groupby('Country of Residence')
dfg

y20['Country of Residence'].value_counts().plot(kind='pie', figsize = (9,9))


y20
# Out:
#   Country of Residence  TOTAL
# 0               India   89357
# 1                  UK   55455
# 2               Russia  49397
# 3              Germany  34507
# 4                China  26147

# %%
'''https://www.sltda.gov.lk/storage/common_media/September-Arrivals-Report97490040.pdf'''
#Tourist Arrival on year 2021

data21 = pd.read_csv('Tourist_2021.csv', index_col=None)
y21 = data21.iloc[:5, :2] 

dfg = data16.groupby('Country of Residence')
dfg

y21['Country of Residence'].value_counts().plot(kind='pie', figsize = (10,10))
y21
# Out:
#   Country of Residence  TOTAL
# 0               India   10060
# 1           Kazakhstan   3200
# 2              Ukraine   2742
# 3              Germany   2704
# 4                  UK    2142

# %%
#All countries visited SL in 2016
'''fig = plt.figure(figsize=(35,15))
ax = fig.add_axes([0,0,1,1])
COR = df['Country of Residence']
pop = df['TOTAL']
ax.bar(COR,pop)
'''
#Top 5 countries visited SL in 2016
fig = plt.figure(figsize=(5,3))
ax = fig.add_axes([0,0,1,1])
COR = b['Country of Residence']
pop = b['TOTAL']
ax.bar(COR,pop)

#Top 5 countries visited SL in 2016
fig = plt.figure(figsize=(5,3))
ax = fig.add_axes([0,0,1,1])
COR = y['Country of Residence']
pop = y['TOTAL']
ax.bar(COR,pop)

plot = y.plot.pie(y='TOTAL', figsize=(7, 7),)
#plot = y.plot.pie(subplots=True, figsize=(11, 6))
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')
np.random.seed(123456)



df = pd.DataFrame(3 * np.random.rand(4, 2), index=['a', 'b', 'c', 'd'], columns=['x', 'y'])

df.plot.pie(subplots=True, figsize=(10,5), autopct='%.2f', fontsize=10, labeldistance=None);

plt.show()

# %%
df = pd.DataFrame({
...    'UK': [20, 18, 489, 161845, 188159],
...    'India': [4, 25, 281, 316247, 356729]
...    }, index=[2012, 2013, 2014, 2015, 2016])
>>> lines = df.plot.line()

# %%
data_url = 'https://datahub.io/nandana/sri-lanka-tourism-statistics/datapackage.json'

# to load Data Package into storage
package = datapackage.Package(data_url)

# to load only tabular data
resources = package.resources
for resource in resources:
    if resource.tabular:
        data = pd.read_csv(resource.descriptor['path'])
        print (data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dp/2ms1d3nx6nq459ycjnlz_p740000gn/T/ipykernel_72413/2689406929.py in <module>
#       2
#       3 # to load Data Package into storage
# ----> 4 package = datapackage.Package(data_url)
#       5
#       6 # to load only tabular data
#
# NameError: name 'datapackage' is not defined
